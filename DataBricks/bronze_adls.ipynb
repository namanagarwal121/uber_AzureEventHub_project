# %%
import pandas as pd

# %%
tables = [
    "bulk_rides",
    "map_cancellation_reasons",
    "map_cities",
    "map_payment_methods",
    "map_ride_statuses",
    "map_vehicle_makes",
    "map_vehicle_types"
]

# %%
for map_cities in tables:
    url = f"https://dlazureuberproject.blob.core.windows.net/bronze/{map_cities}.json?sp=r&st=2026-03-15T04:56:59Z&se=2026-03-25T13:11:59Z&spr=https&sv=2024-11-04&sr=c&sig=%2F5AmQeUevgF9eTthR%2BnNcMPMqC%2FQ%2FHSoAWEUCpTVLdk%3D"
    df = pd.read_json(url)
    df_spark = spark.createDataFrame(df)
    spark.sql(f"drop table uber.bronze.{map_cities}")
    #writing data to the bronze layer
    df_spark.write.mode("overwrite").format("delta").saveAsTable(f"uber.bronze.{map_cities}")

# %%
# %sql
Alter table uber.bronze.map_cities
Add column updated_at timestamp

# %%
# %sql
update  uber.bronze.map_cities
set 
updated_at = getdate()

# %%
# %sql
select * from uber.bronze.map_cities
